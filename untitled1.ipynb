# %% [markdown]
# <a href="https://colab.research.google.com/github/Narendra13512u/Analysis-of-Draught-Monitoring-System/blob/main/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
      print(os.path.join(dirname, filename))

# %%
df=pd.read_csv('/region_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Location  day       date  total_number_positive_people  deaths  \
# 0          10  Toscana    0  24/2/2020                             0       0
# 1          24  Toscana    1  25/2/2020                             2       0
# 2          38  Toscana    2  26/2/2020                             2       0
# 3          52  Toscana    3  27/2/2020                             2       0
# 4          66  Toscana    4  28/2/2020                             8       0
#
#    deaths_increase  total_recoveries  total_recoveries_increase  \
# 0              0.0                 0                        0.0
# 1              0.0                 2                        0.0
# 2              0.0                 2                        0.0
# 3              0.0                 2                        0.0
# 4              0.0                 5                      150.0
#
#    currently_positive  dismissed_patients  swabs  swabs_increase
# ...

# %%
fig = px.line(df, x="date", y="deaths", color='Location', title="Number of deaths")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x="date", y="total_number_positive_people", color='Location', title="Total number of positive people")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x="date", y="total_number_positive_people", color='Location', title="Total number of positive people")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x="date", y="currently_positive", color='Location', title="Currently positives cases")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x="date", y="total_number_positive_people", color='Location', title="Total number of positive people")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x="date", y="deaths", color='Location', title="Death cases")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x="date", y="total_number_positive_people", color='Location', title="Total number of positive people")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    843 non-null    int64
#  1   Location                      843 non-null    object
#  2   day                           843 non-null    int64
#  3   date                          843 non-null    object
#  4   total_number_positive_people  843 non-null    int64
#  5   deaths                        843 non-null    int64
#  6   deaths_increase               843 non-null    float64
#  7   total_recoveries              843 non-null    int64
#  8   total_recoveries_increase     843 non-null    float64
#  9   currently_positive            843 non-null    int64
#  10  dismissed_patients            843 non-null    int64
#  11  swabs                         843 non-null    int64
# ...

# %%
df.iloc[100:,:]
# Out:
#      Unnamed: 0 Location  day       date  total_number_positive_people  \
# 100        1410  Toscana  100  03/6/2020                         10121
# 101        1424  Toscana  101  04/6/2020                         10122
# 102        1438  Toscana  102  05/6/2020                         10129
# 103        1452  Toscana  103  06/6/2020                         10134
# 104        1466  Toscana  104  07/6/2020                         10135
# ..          ...      ...  ...        ...                           ...
# 838       11742  Toscana  838  11/6/2022                       1162512
# 839       11756  Toscana  839  12/6/2022                       1163547
# 840       11770  Toscana  840  13/6/2022                       1163981
# 841       11784  Toscana  841  14/6/2022                       1166162
# 842       11798  Toscana  842  15/6/2022                       1167901
#
#      deaths  deaths_increase  total_recoveries  total_recoveries_increase  \
# ...

# %%
df
# Out:
#      Unnamed: 0 Location  day       date  total_number_positive_people  \
# 0            10  Toscana    0  24/2/2020                             0
# 1            24  Toscana    1  25/2/2020                             2
# 2            38  Toscana    2  26/2/2020                             2
# 3            52  Toscana    3  27/2/2020                             2
# 4            66  Toscana    4  28/2/2020                             8
# ..          ...      ...  ...        ...                           ...
# 838       11742  Toscana  838  11/6/2022                       1162512
# 839       11756  Toscana  839  12/6/2022                       1163547
# 840       11770  Toscana  840  13/6/2022                       1163981
# 841       11784  Toscana  841  14/6/2022                       1166162
# 842       11798  Toscana  842  15/6/2022                       1167901
#
#      deaths  deaths_increase  total_recoveries  total_recoveries_increase  \
# ...

# %%
top=df[df["date"]==df["date"].max()]

# %%
top.tail()
